# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from biokit.viz import corrplot
# Out:
# Creating directory C:\Users\jbsol\AppData\Local\biokit\biokit
# Creating directory C:\Users\jbsol\AppData\Local\bioservices\bioservices

# %%
data = pd.read_csv("HR_comma_sep.csv")
# Initial question: Why are our best and most experienced employees leaving prematurely?

# %%
data.shape
# Out:
# (14999, 10)

# %%
data.head(20)
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.38             0.53               2                   157
# 1                 0.80             0.86               5                   262
# 2                 0.11             0.88               7                   272
# 3                 0.72             0.87               5                   223
# 4                 0.37             0.52               2                   159
# 5                 0.41             0.50               2                   153
# 6                 0.10             0.77               6                   247
# 7                 0.92             0.85               5                   259
# 8                 0.89             1.00               5                   224
# 9                 0.42             0.53               2                   142
# 10                0.45             0.54               2                   135
# ...

# %%
sns.countplot(data['left'])

# %%
g = sns.FacetGrid(data, col="left")
g = g.map(sns.distplot, "satisfaction_level")
# Why would employees who have high satisfaction levels leave?

# %%
sns.boxplot(x = 'left', y = 'satisfaction_level', data = data)

# %%
g = sns.FacetGrid(data, col="left")
g = g.map(sns.distplot, "last_evaluation")

# %%
sns.countplot(data.number_project)

# %%
g = sns.FacetGrid(data, col="left")
g = g.map(sns.countplot, "number_project")

# %%
sns.distplot(data.average_montly_hours)

# %%
g = sns.FacetGrid(data, col="left")
g = g.map(sns.distplot, "average_montly_hours")

# %%
dataDrop = data
del dataDrop['salary']
del dataDrop['sales']

# %%
c = corrplot.Corrplot(dataDrop)
c.plot()
# Out:
# Computing correlation
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-10829458d68c> in <module>()
#       1 c = corrplot.Corrplot(dataDrop)
# ----> 2 c.plot()
#
# C:\Users\jbsol\Anaconda2\lib\site-packages\biokit\viz\corrplot.pyc in plot(self, fig, grid, rotation, lower, upper, shrink, axisbg, colorbar, label_color, fontsize, edgecolor, method, order_method, order_metric, cmap, ax, binarise_color)
#     204         self.edgecolor = edgecolor
#     205
# --> 206         df = self.order(method=order_method, metric=order_metric)
#     207
#     208         # figure can be a number or an instance; otherwise creates it
#
# C:\Users\jbsol\Anaconda2\lib\site-packages\biokit\viz\corrplot.pyc in order(self, method, metric, inplace)
#     118         Z = hierarchy.dendrogram(Y, no_plot=True)
#     119         idx1 = Z['leaves']
# ...
